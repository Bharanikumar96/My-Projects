# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = pd.read_csv("D:\Project\ML PROJECT\diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
numeric_data = data.select_dtypes(include=['float64','int64'])

# %%
numeric_data = numeric_data.fillna(numeric_data.mean())

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_data)

# %%
n_components = 2
pca = PCA(n_components=n_components)
pca_data = pca.fit_transform(scaled_data)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.26138907, 0.19714578])

# %%
plt.figure(figsize=(8,6))
plt.scatter(pca_data[:,0],pca_data[:,1],c='blue',edgecolor='k')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('PCA Scatter Plot')
plt.show()

# %%
pca_transformed_df = pd.DataFrame(pca_data,columns=[f'PC{i+1}'for i in range(n_components)])
pca_transformed_df.to_csv('pca_transformed_data.csv',index=False)
print("PCA-transformed data saved to 'pca_transformed_data.csv'")
# Out:
# PCA-transformed data saved to 'pca_transformed_data.csv'
